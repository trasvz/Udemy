# %%
#Task 1 : Import Numpy

# %%
import numpy as np

# %%
#Task 2 : Create Array 5x5 where all is 10

# %%
np.full((5,5),10)
# Out:
# array([[10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10],
#        [10, 10, 10, 10, 10]])

# %%
#Task 3 : Create an array of random numbers

# %%
np.random.seed(101)
arr = np.random.randint(low=0,high=100,size=(5,5))
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
#Tas 4 : Find the smallest and largest values in the array

# %%
np.max(arr)
# Out:
# 95

# %%
np.min(arr)
# Out:
# 4

# %%
#Task 5 : Use PIL and matplotlib to read and display the image

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
pic = Image.open('img/IMG20170525134042.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1467x1357 at 0x185432653C8>

# %%
#Task 6 : Convert the image to a numpy array

# %%
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (1357, 1467, 3)

# %%
pic_blue = pic_arr.copy()

# %%
pic_blue[:,:,0] = 0
pic_blue[:,:,1] = 0
plt.imshow(pic_blue)
